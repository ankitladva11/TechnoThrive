# %%
import os
from dotenv import load_dotenv
import openai

# Load environment variables from the .env file
load_dotenv()

# Retrieve the API key from the environment variable
api_key = os.getenv("OPENAI_API_KEY")

# Set the API key
openai.api_key = api_key

# Your code for converting CSV to JSONL here...

# %%
import os
import openai
# os.environ["OPEN_AI_API"]='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'
openai.api_key = "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"
openai.File.create(
  file=open("output.jsonl", "rb"),
  purpose='fine-tune'   
)
# Out:
# <File file id=file-Z9bNwFxjLMOKK7HE7hEZs4Gw at 0x1647fabe7f0> JSON: {
#   "object": "file",
#   "id": "file-Z9bNwFxjLMOKK7HE7hEZs4Gw",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 23240,
#   "created_at": 1694756755,
#   "status": "uploaded",
#   "status_details": null
# }

# %%
# openai.FineTuningJob.create(training_file="file-wLcv96mHKn1wCUWLSy8W5ZE2", model="curie")

# %%
fine_tune_response=openai.FineTune.create(training_file="file-Z9bNwFxjLMOKK7HE7hEZs4Gw", model="davinci")

# %%
fine_tuned_model = fine_tune_response.fine_tuned_model

# %%
fine_tune_response
# Out:
# <FineTune fine-tune id=ft-i3tpYekyJsbC99umaNUKytu1 at 0x1647fac2b10> JSON: {
#   "object": "fine-tune",
#   "id": "ft-i3tpYekyJsbC99umaNUKytu1",
#   "hyperparams": {
#     "n_epochs": 4,
#     "batch_size": null,
#     "prompt_loss_weight": 0.01,
#     "learning_rate_multiplier": null
#   },
#   "organization_id": "org-81XXcQp3SUzUwOXQO9KbNLqo",
#   "model": "davinci",
#   "training_files": [
#     {
#       "object": "file",
#       "id": "file-Z9bNwFxjLMOKK7HE7hEZs4Gw",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 23240,
#       "created_at": 1694756755,
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "validation_files": [],
#   "result_files": [],
#   "created_at": 1694756786,
#   "updated_at": 1694756786,
#   "status": "pending",
#   "fine_tuned_model": null,
#   "events": [
#     {
#       "object": "fine-tune-event",
#       "level": "info",
#       "message": "Created fine-tune: ft-i3tpYekyJsbC99umaNUKytu1",
# ...

# %%
import openai

# Set up your OpenAI API key
openai.api_key =  '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'
# List fine-tuned models
response = openai.FineTune.list()

# Print information about fine-tuned models
for model in response['data']:
    print('Model ID:', model['id'])
    print(model)

    # print('Model Name:', model['model_name'])
    # print('Owner:', model['owner'])
    print('-------------------------------------------------------------------------------------')
    # model_1='davinci:ft-personal-2023-09-15-05-49-17'
    # model_id='ft-faKAUOQpYsLn9rQ4Hso7wRLQ'
# Out:
# Model ID: ft-faKAUOQpYsLn9rQ4Hso7wRLQ
# {
#   "object": "fine-tune",
#   "id": "ft-faKAUOQpYsLn9rQ4Hso7wRLQ",
#   "hyperparams": {
#     "n_epochs": 4,
#     "batch_size": 1,
#     "prompt_loss_weight": 0.01,
#     "learning_rate_multiplier": 0.1
#   },
#   "organization_id": "org-81XXcQp3SUzUwOXQO9KbNLqo",
#   "model": "curie",
#   "training_files": [
#     {
#       "object": "file",
#       "id": "file-wLcv96mHKn1wCUWLSy8W5ZE2",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 23240,
#       "created_at": 1694712544,
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "validation_files": [],
#   "result_files": [
#     {
#       "object": "file",
#       "id": "file-T9aK8X3AJAXxo1WHrDz6b6rc",
#       "purpose": "fine-tune-results",
#       "filename": "compiled_results.csv",
#       "bytes": 4073,
#       "created_at": 1694756524,
#       "status": "processed",
#       "status_details": null
#     }
#   ],
# ...

# %%
retrieve_response = openai.FineTune.retrieve(id=fine_tune_response.id)
fine_tuned_model = retrieve_response.fine_tuned_model
print(fine_tuned_model)
# Out:
# None

# %%
model_id='ft-YQFJffHRes5lx1IhdmnriEOZ'
model_name='curie:ft-personal-2023-09-15-06-03-45'

# %%
import openai

# Set up your OpenAI API key
openai.api_key = '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'

# Define the engine ID and model ID
engine_id = model_id
model_name =model_name

# Define the prompt for completion
# while True:
prompt = input('Ask Your Query...')

# Generate completions
response = openai.Completion.create(
model=model_name,
prompt=prompt,
max_tokens=1000,
temperature=0.8
)

# Retrieve the completion from the response
completion = response.choices[0].text.strip()

# Print the completion
print('Completion:', completion)
# Out:
# Completion: is interesnting because itoffers greater protection than what the bankruptcy code might offer, but it does come with some trade offs. The most obvious is that there is more rigidity in the value of the equity than what the debt is technically worth. The equity value has to equal the face value of all debt, plus any lien, plus any guaranteed payment. In corporate reorganizations, there is often an equity buyback to return the company to profitability, so there could be a delay in payment to the equity holders (unless a dividend is declared in advance) , the equity holders suffer in value if the company is unsuccessful and debt holders are paid first.   The equity holders don't necessarily lose their entire investment, but they may lose part of it or receive much less than they thought they would based on the value of the equity.    The equity value is determined by a public auction, just like a foreclosure sale.  Unless otherwise negotiated prior to the public auction, the
# ...
